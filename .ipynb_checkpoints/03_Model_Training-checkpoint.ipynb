# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('processed_data.csv')

# %%
data.head(5)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0    10000.0   36 months     11.44       329.48     B        B4  10+ years
# 1     8000.0   36 months     11.99       265.68     B        B5    4 years
# 2    15600.0   36 months     10.49       506.97     B        B3   < 1 year
# 3     7200.0   36 months      6.49       220.65     A        A2    6 years
# 4    24375.0   60 months     17.27       609.33     C        C5    9 years
#
#   home_ownership  annual_inc verification_status  ... initial_list_status  \
# 0           RENT   11.669938        Not Verified  ...                   w
# 1       MORTGAGE   11.082158        Not Verified  ...                   f
# 2           RENT   10.670303     Source Verified  ...                   f
# 3           RENT   10.896758        Not Verified  ...                   f
# 4       MORTGAGE   10.915107            Verified  ...                   f
#
#   application_type  mort_acc pub_rec_bankruptcies  default  loan_income_ratio  \
# 0       INDIVIDUAL       0.0                  0.0        0           0.085470
# 1       INDIVIDUAL       3.0                  0.0        0           0.123077
# 2       INDIVIDUAL       0.0                  0.0        0           0.362310
# 3       INDIVIDUAL       0.0                  0.0        0           0.133333
# 4       INDIVIDUAL       1.0                  0.0        1           0.443182
#
#    installment_income_ratio  has_bankruptcy  public_record_risk  \
# 0                  0.002816               0                 0.0
# 1                  0.004087               0                 0.0
# 2                  0.011774               0                 0.0
# 3                  0.004086               0                 0.0
# 4                  0.011079               0                 0.0
#
#   high_utilization
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0
#
# [5 rows x 29 columns]

# %%
data['term'] = data['term'].str.strip()
data['term'] = data['term'].str.replace('months','')
data['term'] = data['term'].astype(int)

# %%
data['term'].unique()
# Out:
# array([36, 60])

# %%
# Separate X and Y
x = data.drop('default', axis = 1)
y = data.default

# %%
# Train-Test-Split
from sklearn.model_selection import train_test_split

x_train , x_test, y_train, y_test = train_test_split(x , y, test_size = 0.2, random_state = 42, stratify = y)

# %%
np.isinf(x_train.select_dtypes(include=np.number)).sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# annual_inc                  0
# dti                         0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                  0
# total_acc                   0
# mort_acc                    0
# pub_rec_bankruptcies        0
# loan_income_ratio           1
# installment_income_ratio    1
# has_bankruptcy              0
# public_record_risk          0
# high_utilization            0
# dtype: int64

# %%
x_train = x_train.replace([np.inf, -np.inf], np.nan)
x_test = x_test.replace([np.inf, -np.inf], np.nan)

# %%
num_cols = x_train.select_dtypes(
    include=['int64','float64']
).columns.tolist()

cat_cols = x_train.select_dtypes(
    include=['object']
).columns.tolist()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_2512\1803936624.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = x_train.select_dtypes(

# %%
# Imputation

# %%
# Numeric colums Imputation
from sklearn.impute import SimpleImputer

num_imputer=SimpleImputer(strategy='median')

# %%
num_imputer
# Out:
# SimpleImputer(strategy='median')

# %%
# Categorical columns Imputation
cat_imputer=SimpleImputer(strategy='most_frequent')

# %%
cat_imputer
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
# Encoding : One-Hot Encoding Technique

from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder(handle_unknown='ignore')

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Building Pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
preprocessor=ColumnTransformer([('num',Pipeline([('imputer',num_imputer),('scaler',StandardScaler())]),num_cols),
                                ('cat',Pipeline([('imputer',cat_imputer),('encoder',encoder)]),cat_cols)])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imblearn) (0.14.2)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (2.4.6)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (1.9.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.6 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (0.1.6)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from scikit-learn<2,>=1.4.2->imbalanced-learn->imblearn) (2.7.0)

# %%
from imblearn.pipeline import Pipeline

from imblearn.over_sampling import SMOTE

# %%
x_train['term'].unique()
# Out:
# array([60, 36])

# %% [markdown]
# # Training Model

# %%
# 1. Logistic Regression
from sklearn.linear_model import LogisticRegression

lr = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        class_weight='balanced',
        max_iter=1000
    ))
])

lr.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['loan_amnt', 'term',
#                                                    'int_rate', 'installment',
#                                                    'annual_inc', 'dti',
#                                                    'open_acc', 'pub_rec',
#                                                    'revol_bal', 'revol_util',
#                                                    'total_acc', 'mort_acc',
#                                                    'pub_rec_bankruptcies',
#                                                    'loan_income_ratio',
#                                                    'installment...
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade', 'sub_grade',
#                                                    'emp_length',
#                                                    'home_ownership',
#                                                    'verification_status',
#                                                    'issue_d', 'purpose',
#                                                    'earliest_cr_line',
#                                                    'initial_list_status',
#                                                    'application_type'])])),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from xgboost) (2.4.6)
# Requirement already satisfied: scipy in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from xgboost) (1.17.1)
# Downloading xgboost-3.2.0-py3-none-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#     --------------------------------------- 1.3/101.7 MB 6.7 MB/s eta 0:00:16
#    - -------------------------------------- 2.9/101.7 MB 6.7 MB/s eta 0:00:15
#    - -------------------------------------- 3.4/101.7 MB 6.1 MB/s eta 0:00:17
#    - -------------------------------------- 3.4/101.7 MB 6.1 MB/s eta 0:00:17
#    - -------------------------------------- 3.7/101.7 MB 3.9 MB/s eta 0:00:26
#    - -------------------------------------- 3.9/101.7 MB 3.3 MB/s eta 0:00:30
#    - -------------------------------------- 4.5/101.7 MB 2.8 MB/s eta 0:00:35
#    - -------------------------------------- 4.7/101.7 MB 2.7 MB/s eta 0:00:37
#    - -------------------------------------- 5.0/101.7 MB 2.6 MB/s eta 0:00:37
#    -- ------------------------------------- 5.5/101.7 MB 2.5 MB/s eta 0:00:39
#    -- ------------------------------------- 5.8/101.7 MB 2.5 MB/s eta 0:00:39
#    -- ------------------------------------- 6.0/101.7 MB 2.4 MB/s eta 0:00:41
#    -- ------------------------------------- 6.6/101.7 MB 2.3 MB/s eta 0:00:43
#    -- ------------------------------------- 6.8/101.7 MB 2.2 MB/s eta 0:00:43
#    -- ------------------------------------- 7.3/101.7 MB 2.2 MB/s eta 0:00:43
#    --- ------------------------------------ 8.1/101.7 MB 2.3 MB/s eta 0:00:42
#    --- ------------------------------------ 8.7/101.7 MB 2.3 MB/s eta 0:00:41
#    --- ------------------------------------ 9.2/101.7 MB 2.3 MB/s eta 0:00:41
#    --- ------------------------------------ 9.7/101.7 MB 2.2 MB/s eta 0:00:41
#    --- ------------------------------------ 10.0/101.7 MB 2.2 MB/s eta 0:00:42
#    ---- ----------------------------------- 10.5/101.7 MB 2.2 MB/s eta 0:00:41
#    ---- ----------------------------------- 11.0/101.7 MB 2.2 MB/s eta 0:00:41
#    ---- ----------------------------------- 11.5/101.7 MB 2.2 MB/s eta 0:00:41
#    ---- ----------------------------------- 12.3/101.7 MB 2.3 MB/s eta 0:00:40
#    ----- ---------------------------------- 12.8/101.7 MB 2.3 MB/s eta 0:00:40
#    ----- ---------------------------------- 13.1/101.7 MB 2.3 MB/s eta 0:00:40
#    ----- ---------------------------------- 13.4/101.7 MB 2.2 MB/s eta 0:00:41
#    ----- ----------------------------------
#    --------------------------------- ------ 84.9/101.7 MB 1.2 MB/s eta 0:00:14
#    --------------------------------- ------ 85.2/101.7 MB 1.2 MB/s eta 0:00:14
#    --------------------------------- ------ 85.5/101.7 MB 1.2 MB/s eta 0:00:14
#    --------------------------------- ------ 85.7/101.7 MB 1.2 MB/s eta 0:00:14
#    --------------------------------- ------ 86.2/101.7 MB 1.2 MB/s eta 0:00:13
#    ---------------------------------- ----- 86.5/101.7 MB 1.2 MB/s eta 0:00:13
#    ---------------------------------- ----- 86.8/101.7 MB 1.2 MB/s eta 0:00:13
#    ---------------------------------- ----- 86.8/101.7 MB 1.2 MB/s eta 0:00:13
#    ---------------------------------- ----- 87.3/101.7 MB 1.2 MB/s eta 0:00:12
#    ---------------------------------- ----- 87.6/101.7 MB 1.2 MB/s eta 0:00:12
#    ---------------------------------- ----- 87.8/101.7 MB 1.2 MB/s eta 0:00:12
#    ---------------------------------- ----- 88.1/101.7 MB 1.2 MB/s eta 0:00:12
#    ---------------------------------- ----- 88.3/101.7 MB 1.2 MB/s eta 0:00:11
#    ---------------------------------- ----- 88.6/101.7 MB 1.2 MB/s eta 0:00:11
#    ---------------------------------- ----- 88.9/101.7 MB 1.2 MB/s eta 0:00:11
#    ----------------------------------- ---- 89.1/101.7 MB 1.2 MB/s eta 0:00:11
#    ----------------------------------- ---- 89.4/101.7 MB 1.2 MB/s eta 0:00:10
#    ----------------------------------- ---- 89.7/101.7 MB 1.2 MB/s eta 0:00:10
#    ----------------------------------- ---- 89.9/101.7 MB 1.2 MB/s eta 0:00:10
#    ----------------------------------- ---- 90.2/101.7 MB 1.2 MB/s eta 0:00:10
#    ----------------------------------- ---- 90.4/101.7 MB 1.2 MB/s eta 0:00:10
#    ----------------------------------- ---- 90.7/101.7 MB 1.2 MB/s eta 0:00:09
#    ----------------------------------- ---- 91.0/101.7 MB 1.2 MB/s eta 0:00:09
#    ----------------------------------- ---- 91.2/101.7 MB 1.2 MB/s eta 0:00:09
#    ----------------------------------- ---- 91.5/101.7 MB 1.2 MB/s eta 0:00:09
#    ------------------------------------ --- 91.8/101.7 MB 1.2 MB/s eta 0:00:09
#    ------------------------------------ --- 92.0/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 92.0/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 92.3/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 92.8/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 92.8/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 93.1/101.7 MB 1.2 MB/s eta 0:00:08
#    ------------------------------------ --- 93.3/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------ --- 93.6/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------ --- 93.8/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------- -- 94.1/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------- -- 94.4/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------- -- 94.4/101.7 MB 1.2 MB/s eta 0:00:07
#    ------------------------------------- -- 94.6/101.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------------------- -- 94.9/101.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------------------- -- 95.4/101.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------------------- -- 95.7/101.7 MB 1.2 MB/s eta 0:00:05
#    ------------------------------------- -- 95.7/101.7 MB 1.2 MB/s eta 0:00:05
#    ------------------------------------- -- 96.2/101.7 MB 1.2 MB/s eta 0:00:05
#    -------------------------------------- - 96.7/101.7 MB 1.2 MB/s eta 0:00:05
#    -------------------------------------- - 97.5/101.7 MB 1.2 MB/s eta 0:00:04
#    -------------------------------------- - 98.0/101.7 MB 1.3 MB/s eta 0:00:03
#    -------------------------------------- - 98.3/101.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------------------- - 98.3/101.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------------------- - 98.6/101.7 MB 1.2 MB/s eta 0:00:03
#    -------------------------------------- - 98.8/101.7 MB 1.2 MB/s eta 0:00:03
#    ---------------------------------------  99.4/101.7 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------------  99.6/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  99.9/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  100.1/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  100.1/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  100.1/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  100.1/101.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------------  100.4/101.7 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------------  101.4/101.7 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  101.4/101.7 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 1.3 MB/s  0:01:15
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0

# %%
# 2. XGBoost
from xgboost import XGBClassifier
xgb = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        eval_metric='logloss',
        random_state=42
    ))
])
xgb.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['loan_amnt', 'term',
#                                                    'int_rate', 'installment',
#                                                    'annual_inc', 'dti',
#                                                    'open_acc', 'pub_rec',
#                                                    'revol_bal', 'revol_util',
#                                                    'total_acc', 'mort_acc',
#                                                    'pub_rec_bankruptcies',
#                                                    'loan_income_ratio',
#                                                    'installment...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from lightgbm) (2.4.6)
# Requirement already satisfied: scipy in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from lightgbm) (1.17.1)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------------------------------ --- 1.3/1.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.2 MB/s  0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
# 3. LightGBM
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier

lgbm = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        random_state=42
    ))
])

lgbm.fit(x_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 62138, number of negative: 254686
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.258434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3952
# [LightGBM] [Info] Number of data points in the train set: 316824, number of used features: 730
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.196128 -> initscore=-1.410674
# [LightGBM] [Info] Start training from score -1.410674
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['loan_amnt', 'term',
#                                                    'int_rate', 'installment',
#                                                    'annual_inc', 'dti',
#                                                    'open_acc', 'pub_rec',
#                                                    'revol_bal', 'revol_util',
#                                                    'total_acc', 'mort_acc',
#                                                    'pub_rec_bankruptcies',
#                                                    'loan_income_ratio',
#                                                    'installment...
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['grade', 'sub_grade',
#                                                    'emp_length',
#                                                    'home_ownership',
#                                                    'verification_status',
#                                                    'issue_d', 'purpose',
#                                                    'earliest_cr_line',
#                                                    'initial_list_status',
#                                                    'application_type'])])),
#                 ('model',
#                  LGBMClassifier(learning_rate=0.05, n_estimators=300,
#                                 random_state=42))])

# %%
#Evaluate All Models

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

# %%
# Prediction for logistic regression model
lr_pred = lr.predict(x_test)
lr_prob = lr.predict_proba(x_test)[:, 1]

# %%
print("========== Logistic Regression ==========")

print("Accuracy :", accuracy_score(y_test, lr_pred))
print("Precision:", precision_score(y_test, lr_pred))
print("Recall   :", recall_score(y_test, lr_pred))
print("F1 Score :", f1_score(y_test, lr_pred))
print("ROC-AUC  :", roc_auc_score(y_test, lr_prob))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, lr_pred))

print("\nClassification Report")
print(classification_report(y_test, lr_pred))
# Out:
# ========== Logistic Regression ==========
# Accuracy : 0.6550008837714315
# Precision: 0.31981417524985484
# Recall   : 0.6735757965883489
# F1 Score : 0.43370497782567247
# ROC-AUC  : 0.7229922859858363
#
# Confusion Matrix
# [[41416 22255]
#  [ 5071 10464]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75     63671
#            1       0.32      0.67      0.43     15535
#
#     accuracy                           0.66     79206
#    macro avg       0.61      0.66      0.59     79206
# weighted avg       0.78      0.66      0.69     79206

# %%
# Prediction for XGBoost
xgb_pred = xgb.predict(x_test)
xgb_prob = xgb.predict_proba(x_test)[:,1]

# %%
print("========== XGBoost ==========")

print("Accuracy :", accuracy_score(y_test, xgb_pred))
print("Precision:", precision_score(y_test, xgb_pred))
print("Recall   :", recall_score(y_test, xgb_pred))
print("F1 Score :", f1_score(y_test, xgb_pred))
print("ROC-AUC  :", roc_auc_score(y_test, xgb_prob))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, xgb_pred))

print("\nClassification Report")
print(classification_report(y_test, xgb_pred))
# Out:
# ========== XGBoost ==========
# Accuracy : 0.8086887357018407
# Precision: 0.5896713615023474
# Recall   : 0.08084969423881558
# F1 Score : 0.1422020945372205
# ROC-AUC  : 0.7279749121900416
#
# Confusion Matrix
# [[62797   874]
#  [14279  1256]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89     63671
#            1       0.59      0.08      0.14     15535
#
#     accuracy                           0.81     79206
#    macro avg       0.70      0.53      0.52     79206
# weighted avg       0.77      0.81      0.75     79206

# %%
# Prediction for LightGBM
lgbm_pred = lgbm.predict(x_test)
lgbm_prob = lgbm.predict_proba(x_test)[:,1]
# Out:
# C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
print("========== LightGBM ==========")

print("Accuracy :", accuracy_score(y_test, lgbm_pred))
print("Precision:", precision_score(y_test, lgbm_pred))
print("Recall   :", recall_score(y_test, lgbm_pred))
print("F1 Score :", f1_score(y_test, lgbm_pred))
print("ROC-AUC  :", roc_auc_score(y_test, lgbm_prob))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, lgbm_pred))

print("\nClassification Report")
print(classification_report(y_test, lgbm_pred))
# Out:
# ========== LightGBM ==========
# Accuracy : 0.8090801201929146
# Precision: 0.5841140529531568
# Recall   : 0.09230769230769231
# F1 Score : 0.1594219010561423
# ROC-AUC  : 0.7292336711778797
#
# Confusion Matrix
# [[62650  1021]
#  [14101  1434]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89     63671
#            1       0.58      0.09      0.16     15535
#
#     accuracy                           0.81     79206
#    macro avg       0.70      0.54      0.53     79206
# weighted avg       0.77      0.81      0.75     79206

# %%
# Comparison Table
results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "XGBoost",
        "LightGBM"
    ],

    "Accuracy": [
        accuracy_score(y_test, lr_pred),
        accuracy_score(y_test, xgb_pred),
        accuracy_score(y_test, lgbm_pred)
    ],

    "Precision": [
        precision_score(y_test, lr_pred),
        precision_score(y_test, xgb_pred),
        precision_score(y_test, lgbm_pred)
    ],

    "Recall": [
        recall_score(y_test, lr_pred),
        recall_score(y_test, xgb_pred),
        recall_score(y_test, lgbm_pred)
    ],

    "F1 Score": [
        f1_score(y_test, lr_pred),
        f1_score(y_test, xgb_pred),
        f1_score(y_test, lgbm_pred)
    ],

    "ROC-AUC": [
        roc_auc_score(y_test, lr_prob),
        roc_auc_score(y_test, xgb_prob),
        roc_auc_score(y_test, lgbm_prob)
    ]
})

results = results.sort_values(
    by="ROC-AUC",
    ascending=False
)

results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 2             LightGBM  0.809080   0.584114  0.092308  0.159422  0.729234
# 1              XGBoost  0.808689   0.589671  0.080850  0.142202  0.727975
# 0  Logistic Regression  0.655001   0.319814  0.673576  0.433705  0.722992

# %%
# Best model
best_model = lr

# %%
# SHAP Explainability
# !pip install shap
# Out:
# Requirement already satisfied: shap in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (0.51.0)
# Requirement already satisfied: numpy>=2 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (2.4.6)
# Requirement already satisfied: scipy in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (1.17.1)
# Requirement already satisfied: scikit-learn in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (1.9.0)
# Requirement already satisfied: pandas in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (3.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (4.68.3)
# Requirement already satisfied: packaging>20.9 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (0.66.0)
# Requirement already satisfied: llvmlite in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (0.48.0)
# Requirement already satisfied: cloudpickle in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: colorama in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from pandas->shap) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from scikit-learn->shap) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\patel\anaconda3\envs\newenv\Lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
# ============================================
# SHAP Explainability for Logistic Regression
# ============================================

import shap
import numpy as np
import matplotlib.pyplot as plt

# Extract model and preprocessor from pipeline
model = lr.named_steps['model']
preprocessor = lr.named_steps['preprocessor']

# Transform train and test data
X_train_processed = preprocessor.transform(x_train)
X_test_processed = preprocessor.transform(x_test)

# Get transformed feature names
feature_names = preprocessor.get_feature_names_out()

# Create SHAP explainer
explainer = shap.LinearExplainer(model, X_train_processed)

# Calculate SHAP values
shap_values = explainer.shap_values(X_test_processed)

# ============================
# SHAP Summary Plot (Beeswarm)
# ============================
plt.figure(figsize=(10,6))
shap.summary_plot(
    shap_values,
    X_test_processed,
    feature_names=feature_names,
    show=False
)
plt.tight_layout()
plt.show()

# ============================
# SHAP Feature Importance (Bar)
# ============================
plt.figure(figsize=(10,6))
shap.summary_plot(
    shap_values,
    X_test_processed,
    feature_names=feature_names,
    plot_type="bar",
    show=False
)
plt.tight_layout()
plt.show()

sample_index = 0

sample = X_test_processed[sample_index]

if hasattr(sample, "toarray"):
    sample = sample.toarray().flatten()

waterfall_exp = shap.Explanation(
    values=shap_values[sample_index],
    base_values=explainer.expected_value,
    data=sample,
    feature_names=feature_names
)

shap.plots.waterfall(waterfall_exp)

# %%
# Threshold Optimization
prob = lr.predict_proba(x_test)[:,1]
import pandas as pd
from sklearn.metrics import precision_score, recall_score

thresholds = [0.30, 0.40, 0.50, 0.60]

results = []

for t in thresholds:

    pred = (prob >= t).astype(int)

    results.append({
        "Threshold": t,
        "Precision": precision_score(y_test, pred),
        "Recall": recall_score(y_test, pred),
        "Approval Rate": (pred == 0).mean()
    })

threshold_df = pd.DataFrame(results)

threshold_df
# Out:
#    Threshold  Precision    Recall  Approval Rate
# 0        0.3   0.239902  0.921403       0.246698
# 1        0.4   0.275395  0.820406       0.415713
# 2        0.5   0.319814  0.673576       0.586913
# 3        0.6   0.379343  0.486321       0.748554

# %%
# Business Impact Analysis
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, lr_pred)

tn, fp, fn, tp = cm.ravel()

print(cm)
# Out:
# [[41416 22255]
#  [ 5071 10464]]

# %%
y_prob = lr.predict_proba(x_test)[:,1]
print(y_prob[:10])
y_pred = (y_prob >= 0.5).astype(int)
print(y_pred[:10])
final_threshold = 0.45
# Out:
# [0.20963025 0.51135472 0.64716914 0.37686768 0.61144812 0.38653388
#  0.68371082 0.25854952 0.48169097 0.44936635]
# [0 1 1 0 1 0 1 0 0 0]

# %%
y_final = (y_prob >= final_threshold).astype(int)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print(cm)
# Out:
# [[41416 22255]
#  [ 5071 10464]]

# %%
# Assumption
avg_loan_amount = 500000  # ₹5 lakh
loss_rate = 0.60         # 60% loss on default

baseline_loss = (tp + fn) * avg_loan_amount * loss_rate

model_loss = fn * avg_loan_amount * loss_rate

savings = baseline_loss - model_loss

print("Baseline Loss:", baseline_loss)
print("Model Loss:", model_loss)
print("Savings:", savings)
# Out:
# Baseline Loss: 4660500000.0
# Model Loss: 1521300000.0
# Savings: 3139200000.0

# %%
# Model Saving
import pickle

pickle.dump(lr, open("model.pkl", "wb"))

# Save preprocessor
pickle.dump(
    lr.named_steps["preprocessor"],
    open("preprocessor.pkl", "wb")
)

# Save logistic regression model only
pickle.dump(
    lr.named_steps["model"],
    open("logistic_model.pkl", "wb")
)

# %%
data.to_csv("credit_risk_model_dataset.csv", index=False)

# %%
for col in [
    'grade',
    'sub_grade',
    'emp_length',
    'home_ownership',
    'verification_status',
    'issue_d',
    'purpose',
    'earliest_cr_line',
    'initial_list_status',
    'application_type'
]:
    print(f"\n{col}")
    print(sorted(data[col].dropna().unique()))
# Out:
# grade
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']
#
# sub_grade
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']
#
# emp_length
# ['1 year', '10+ years', '2 years', '3 years', '4 years', '5 years', '6 years', '7 years', '8 years', '9 years', '< 1 year']
#
# home_ownership
# ['ANY', 'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT']
#
# verification_status
# ['Not Verified', 'Source Verified', 'Verified']
#
# issue_d
# ['Apr-2008', 'Apr-2009', 'Apr-2010', 'Apr-2011', 'Apr-2012', 'Apr-2013', 'Apr-2014', 'Apr-2015', 'Apr-2016', 'Aug-2007', 'Aug-2008', 'Aug-2009', 'Aug-2010', 'Aug-2011', 'Aug-2012', 'Aug-2013', 'Aug-2014', 'Aug-2015', 'Aug-2016', 'Dec-2007', 'Dec-2008', 'Dec-2009', 'Dec-2010', 'Dec-2011', 'Dec-2012', 'Dec-2013', 'Dec-2014', 'Dec-2015', 'Dec-2016', 'Feb-2008', 'Feb-2009', 'Feb-2010', 'Feb-2011', 'Feb-2012', 'Feb-2013', 'Feb-2014', 'Feb-2015', 'Feb-2016', 'Jan-2008', 'Jan-2009', 'Jan-2010', 'Jan-2011', 'Jan-2012', 'Jan-2013', 'Jan-2014', 'Jan-2015', 'Jan-2016', 'Jul-2007', 'Jul-2008', 'Jul-2009', 'Jul-2010', 'Jul-2011', 'Jul-2012', 'Jul-2013', 'Jul-2014', 'Jul-2015', 'Jul-2016', 'Jun-2007', 'Jun-2008', 'Jun-2009', 'Jun-2010', 'Jun-2011', 'Jun-2012', 'Jun-2013', 'Jun-2014', 'Jun-2015', 'Jun-2016', 'Mar-2008', 'Mar-2009', 'Mar-2010', 'Mar-2011', 'Mar-2012', 'Mar-2013', 'Mar-2014', 'Mar-2015', 'Mar-2016', 'May-2008', 'May-2009', 'May-2010', 'May-2011', 'May-2012', 'May-2013', 'May-2014', 'May-2015', 'May-2016', 'Nov-2007', 'Nov-2008', 'Nov-2009', 'Nov-2010', 'Nov-2011', 'Nov-2012', 'Nov-2013', 'Nov-2014', 'Nov-2015', 'Nov-2016', 'Oct-2007', 'Oct-2008', 'Oct-2009', 'Oct-2010', 'Oct-2011', 'Oct-2012', 'Oct-2013', 'Oct-2014', 'Oct-2015', 'Oct-2016', 'Sep-2007', 'Sep-2008', 'Sep-2009', 'Sep-2010', 'Sep-2011', 'Sep-2012', 'Sep-2013', 'Sep-2014', 'Sep-2015', 'Sep-2016']
#
# purpose
# ['car', 'credit_card', 'debt_consolidation', 'educational', 'home_improvement', 'house', 'major_purchase', 'medical', 'moving', 'other', 'renewable_energy', 'small_business', 'vacation', 'wedding']
#
# earliest_cr_line
